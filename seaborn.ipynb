# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Scatter Plot

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips)
plt.show()

# %% [markdown]
# ### Hue, Style and Size

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker')
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time')
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, hue = 'smoker', style = 'time', size = 'size')
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'size')
plt.show()

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, style = 'smoker')
plt.show()

# %%
tips.smoker.value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x = 'total_bill', y = 'tip', data = tips, size = 'size', sizes = (15, 100))
plt.show()

# %% [markdown]
# ### Line plot

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(dict(time = np.arange(500), value = randn(500).cumsum()))
df.head()
# Out:
#    time     value
# 0     0 -0.411758
# 1     1 -1.385222
# 2     2 -1.997110
# 3     3 -1.402349
# 4     4 -1.074854

# %%
sns.relplot(x = 'time', y = 'value', kind = 'line', data = df)
plt.show()

# %%
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, label = 'signal')
plt.legend()
plt.show()

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, label = 'signal', height = 5,  aspect = 2)
plt.legend(loc = 'right')
plt.show()

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', data = fmri, estimator = None, label = 'signal', height = 4, aspect = 2)
plt.legend(loc = 'right')
plt.show()

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', hue = 'event', data = fmri, label = 'Signal', height = 4, aspect = 2)
plt.legend(loc='right')
plt.show()

# %%
sns.relplot(x = 'timepoint', y = 'signal', kind = 'line', hue = 'event', style = 'region', data = fmri, label = 'Signal', height = 5, aspect = 2)
plt.legend(loc='right')
plt.show()

# %%
dots = sns.load_dataset('dots').query("align == 'dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line')
plt.show()

# %%
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style = 'choice')
plt.show()

# %%
pallette = sns.cubehelix_palette(light = 0.9, n_colors = 6)
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style = 'choice', palette = pallette)
plt.show()

# %%
sns.relplot(x = 'time', y = 'firing_rate', data = dots, kind = 'line', hue = 'coherence', style = 'choice', size = 'choice')
plt.show()

# %% [markdown]
# ### Subplots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'smoker', data = tips)
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips)
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'size', data = tips, col_wrap = 3)
plt.show()

# %%
sns.relplot(x = 'total_bill', y = 'tip', hue = 'smoker', col = 'time', row = 'size', data = tips)
plt.show()

# %% [markdown]
# ### Using sns.lineplot() and sns.scatterplot()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = 'timepoint', y = 'signal', hue = 'region', style = 'event', data = fmri,
             ci = 68, err_style = 'bars', markers = True)
plt.show()

# %%
sns.lineplot(x = 'timepoint', y = 'signal', hue = 'event', data = fmri.query("region == 'frontal'"), ci = None)
plt.show()

# %%
plt.figure(figsize = (14, 6))
sns.scatterplot(x = 'total_bill', y = 'tip', hue = 'smoker', style = 'time', size = 'size', data = tips)
plt.show()

# %% [markdown]
# ## Categorical Data Ploting

# %% [markdown]
# ### Cat Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)
plt.show()

# %%
sns.catplot(x = 'total_bill', y = 'day', data = tips)
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, jitter = False)
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm')
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'swarm', hue = 'size')
plt.show()

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips)
plt.show()

# %%
sns.catplot(x = 'smoker', y = 'tip', data = tips, order = ['No', 'Yes'])
plt.show()

# %% [markdown]
# ### Box Plot

# %%
sns.catplot(x = 'day', y = 'total_bill',kind = 'box', data = tips)
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill',kind = 'box', hue = 'sex', data = tips)
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill',kind = 'box', hue = 'sex', data = tips, dodge = False)
plt.show()

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
plt.show()

# %% [markdown]
# ### Boxen Plot

# %%
diamonds = sns.load_dataset('diamonds')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds)
plt.show()

# %%
sns.catplot(x = 'color', y = 'price', kind = 'boxen', data = diamonds, hue = 'cut')
plt.show()

# %% [markdown]
# ### Violin Plot

# %%
sns.catplot(x = 'total_bill', y = 'day', data = tips, kind = 'violin')
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin', hue = 'sex')
plt.show()

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin', hue = 'sex', split = True)
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic)
plt.show()

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class')
plt.show()

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'bar', data = titanic, hue = 'class', palette='ch:0.65')
plt.show()

# %% [markdown]
# ### Point Plot

# %%
sns.catplot(x = 'sex', y = 'survived', kind = 'point', data = titanic)
plt.show()

# %%
sns.catplot(x = 'sex', y = 'survived',hue = 'class', kind = 'point', data = titanic)
plt.show()

# %% [markdown]
# ### Joint Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)
plt.show()

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'hex')
plt.show()

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'kde')
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
sns.pairplot(tips)
plt.show()

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, n_levels = 10)
plt.show()

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)
plt.show()

# %% [markdown]
# ### Regression Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x = 'total_bill', y = 'tip', data = tips)
plt.show()

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)
plt.show()

# %%
sns.lmplot(x = 'size', y = 'tip', data = tips)
plt.show()

# %% [markdown]
# ### Controlling Ploted Figure Aesthetics
# - figure styling
# - axes styling
# - color palettes
# - etc..

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1, 7):
        plt.plot(x, np.sin(x + i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sinplot(-1)

# %%
sns.set_style('ticks', {'axes.grid':True, 'xticks.direction':'in'})
sinplot()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xticks.direction': 'in'})
sinplot()
sns.despine()

# %%
sns.set_style('ticks', {'axes.grid': True, 'xticks.direction': 'in'})
sinplot()
sns.despine(left = True)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'patch.force_edgecolor': True,
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('darkgrid')
sinplot()
