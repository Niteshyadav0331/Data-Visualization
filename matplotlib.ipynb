# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import randint
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ### Line Plot

# %%
x = np.linspace(1, 10, 20)
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y = randint(1, 50, 20)
y
# Out:
# array([31,  3,  3, 49, 27, 25, 32,  3, 17, 16, 26, 35,  2, 11, 46, 17, 10,
#        48,  4, 17])

# %%
plt.plot(y)

# %%
y = y.cumsum()

# %%
plt.plot(y)

# %%
plt.plot(x, y)

# %%
plt.plot(x, y, color = 'r', marker = 'o')

# %%
plt.plot(x, y, color = 'r', marker = 'o', linestyle = '--')

# %% [markdown]
# ### Labels

# %%
plt.figure(figsize = (10, 5))
plt.plot(x, y, color = 'r', marker = '*', linestyle = '--')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('This is a demo plot')
plt.show()

# %% [markdown]
# ### Scatter, Bar, Hist, and Box Plots

# %%
x, y
# Out:
# (array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#          3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#          5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#          8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ]),
#  array([ 31,  34,  37,  86, 113, 138, 170, 173, 190, 206, 232, 267, 269,
#         280, 326, 343, 353, 401, 405, 422], dtype=int32))

# %%
sns.set_style('dark')
plt.scatter(x, y, linewidth = 3)
plt.show()

# %%
b = [10, 23, 43, 5, 66]
a = ['a', 'b', 'c', 'd', 'e']

plt.bar(a, b, width = 0.9)
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.hist(y, bins = 30)
plt.show()

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 3)]

# %%
data[0]
# Out:
# array([-0.20349702, -0.32911708, -0.32739076, -0.32086983, -0.67364289,
#         1.0228421 ,  1.22115176,  0.05909573, -1.54347246, -0.53431506,
#         0.79524806, -2.26938686, -0.50426815, -1.3914099 ,  1.85359847,
#         1.45640081, -0.78336745, -0.69266534,  0.85307286, -0.74191199,
#         1.17511246, -0.02594245, -0.81413807, -0.74385262,  2.32492474,
#         0.97340034,  0.6261869 , -0.07939191,  0.63435   ,  1.19134577,
#        -0.62713661, -0.73028141,  2.46281955,  0.16720991,  0.02309228,
#         0.63295858,  0.32890378,  2.14054657,  1.48579999,  0.67445813,
#        -0.65759474,  0.04845544, -0.07309068, -0.17310508, -1.32224795,
#        -0.66259346,  0.79946284, -1.69224964, -0.60596052,  1.15575587,
#         0.3918831 , -2.3632101 ,  0.10570892, -0.62583681, -0.08399066,
#        -0.10610468, -0.75240459,  0.72821491, -0.4461656 ,  1.09326263,
#         0.16801765,  0.88256983, -1.00035248,  1.52064523, -1.82925086,
#         0.88570239, -1.42030245,  1.16521756, -0.24545124,  1.39007984,
#        -0.20261122,  0.02360824, -0.78335481,  0.73187574, -0.64274229,
#         0.77452147, -0.50347064, -1.43337429,  0.50990207, -0.61545645,
#        -0.04338615, -1.14776924,  0.99425134,  1.61311461, -0.67471313,
#        -0.74191363, -0.23137622,  1.35142423, -1.0750538 , -0.44161473,
#        -0.03476698, -0.73863859,  0.67702675,  0.90922041, -0.90971917,
#        -0.37634201,  0.24089665, -1.37627114,  1.18763156, -1.43289551])

# %%
data[1]
# Out:
# array([ 3.31210665, -2.45606895,  0.58415272, -1.36355193, -0.06665052,
#        -3.36019085,  4.28412694,  1.38850767,  0.41499493,  2.73750049,
#         0.76359809,  1.05037812, -0.75546824, -0.71980799,  3.17119513,
#         0.66591649,  1.39348339, -2.16192264,  1.05434819,  3.2754332 ,
#        -1.69539389, -2.94057679,  0.45406042,  1.30091929,  2.04234935,
#        -1.83109354, -1.79904   , -0.18685059,  2.80893799,  2.93942134,
#        -1.43455333, -0.78827393, -1.92555767, -0.23355152,  0.0169157 ,
#         0.5042704 , -0.45164576, -1.02284687, -0.90474255, -1.43877262,
#         1.61803504,  0.39142837, -0.57588492,  1.27052079,  0.96423713,
#        -0.20621387,  0.81655533, -0.9628473 , -2.62016852, -3.01168159,
#         1.92118975, -2.37562924,  3.50019812, -0.06599475,  2.09370459,
#        -2.4155143 ,  1.74586428, -1.60215213,  2.15619675, -1.46493271,
#         3.02532955, -1.3039583 , -1.92367694, -1.8494812 ,  0.22088371,
#         2.25668067, -0.87049508,  0.36176522, -0.43896709, -1.88409217,
#         3.97655223,  0.67450919, -0.34074449,  1.00470138, -1.88266658,
#         0.1155939 , -3.4140662 , -0.04577733,  0.21162568, -0.41469269,
#        -0.38508315,  2.41852056, -1.89709404, -2.66526624,  0.64797358,
#         0.59241102, -2.15640321,  3.42826398,  4.98849978,  1.18252108,
#         0.8841966 ,  2.23134765, -1.81793011,  0.14128649,  4.06259635,
#         3.00339146,  1.00860317,  1.6734548 , -2.96966646, -2.14024428])

# %%
plt.boxplot(data)
plt.show()

# %%
plt.boxplot(data, vert = False, patch_artist = True)
plt.show()

# %% [markdown]
# ### Subplot

# %%
x
# Out:
# array([ 1.        ,  1.47368421,  1.94736842,  2.42105263,  2.89473684,
#         3.36842105,  3.84210526,  4.31578947,  4.78947368,  5.26315789,
#         5.73684211,  6.21052632,  6.68421053,  7.15789474,  7.63157895,
#         8.10526316,  8.57894737,  9.05263158,  9.52631579, 10.        ])

# %%
y
# Out:
# array([ 31,  34,  37,  86, 113, 138, 170, 173, 190, 206, 232, 267, 269,
#        280, 326, 343, 353, 401, 405, 422], dtype=int32)

# %%
y2 = y*x
y2
# Out:
# array([  31.        ,   50.10526316,   72.05263158,  208.21052632,
#         327.10526316,  464.84210526,  653.15789474,  746.63157895,
#         910.        , 1084.21052632, 1330.94736842, 1658.21052632,
#        1798.05263158, 2004.21052632, 2487.89473684, 2780.10526316,
#        3028.36842105, 3630.10526316, 3858.15789474, 4220.        ])

# %%
plt.figure(figsize = (8, 5))
plt.plot(x, y)
plt.plot(x, y2)
plt.show()

# %%
plt.figure(figsize = (8, 5))
sns.set_style('white')

plt.subplot(1, 2, 1)
plt.plot(x, y)

plt.subplot(1, 2, 2)
plt.plot(x, y2)

plt.show()

# %%
plt.figure(figsize = (8, 5))
sns.set_style('white')

plt.subplot(1, 2, 1)
plt.plot(x, y, marker = 'o', color = 'r')

plt.subplot(1, 2, 2)
plt.plot(x, y2, marker = '*', color = 'k', markersize = 10)

plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.1, 0.6, 0.4, 0.3])

ax1.plot(x, y, 'r')
ax1.set_xlabel("X")
ax1.set_ylabel('Y')
ax1.set_title('Y Plot')

ax2.plot(x, y2, 'g')
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_title('Y2 Plot')

plt.show()

# %% [markdown]
# ### xlim, ylim, xticks, and yticks

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)

ax[1].plot(x, y**2, 'k')
ax[1].set_ylim([2000, 5000])
ax[1].set_xlim([-2, 5])
# Out:
# (-2, 5)

# %%
fig, ax = plt.subplots(1, 2, figsize = (12, 4))

ax[0].plot(x, y, x, y2)
ax[0].set_xticks([1, 4, 9])

ax[1].plot(x, y**2, 'k')
ax[1].set_xticks([1, 4, 9])
ax[1].set_xticklabels([r"$\alpha$", r"$\beta$", "$\delta$"])
# Out:
# [Text(0, 0, '$\\alpha$'), Text(0, 0, '$\\beta$'), Text(0, 0, '$\\delta$')]

# %% [markdown]
# ### Pie Plot

# %%
labels = ['Frogs', 'Cats', 'Dogs', 'Lions']
sizes = [15, 30, 45, 80]

# %%
fig, ax = plt.subplots(figsize = (4, 4), dpi = 100)
explode = (0, 0.1, 0, 0)
ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True, startangle = 90, explode = explode)
plt.show()

# %% [markdown]
# ### Pie Plot Text Color

# %%
fig, ax = plt.subplots(figsize = (4, 4), dpi = 100)
explode = (0, 0.1, 0, 0)
patches, texts, autotexts = ax.pie(sizes, labels = labels, autopct = '%1.1f%%', shadow = True,
                                   startangle = 90, explode = explode)
plt.setp(texts, size = 14, color = 'grey')
plt.setp(autotexts, size = 11, color = 'white')
autotexts[1].set_color('black')
plt.show()

# %% [markdown]
# ### Nested Pie Chart

# %%
fig, ax = plt.subplots(dpi = 100)
size = 0.3

vals = np.array([[60, 32], [35, 20], [26, 36]])
vals_sum = vals.sum(axis = 1)
vals_flat = vals.flatten()

cmap = plt.get_cmap('tab20c')
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap(np.arange(6)*3)

ax.pie(vals_sum, radius = 1, colors = outer_colors, wedgeprops = dict(width = size, edgecolor = 'w'))

ax.pie(vals_flat, radius = 1 - size, colors = inner_colors, wedgeprops = dict(width = size, edgecolor = 'w'))

plt.show()

# %% [markdown]
# ### Labeling Pie Chart

# %%
fig, ax = plt.subplots(dpi = 150)
recipe = ["375 g Flour", "75 g Suger", "250 g Butter", "300 g Berries"]

data = [float(x.split(' ')[0]) for x in recipe]
ingredients = [x.split(' ')[-1] for x in recipe]

def func(pct, vals):
    absolute = int(pct/100.*np.sum(vals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)

wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data), textprops = dict(color = 'w'))

ax.legend(wedges, ingredients, title = 'Ingredients', loc = 'center left', bbox_to_anchor = (1, 0, 1, 1))

plt.show()
